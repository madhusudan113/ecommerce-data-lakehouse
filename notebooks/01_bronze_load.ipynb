# %%
# Create Project Folders

dbutils.fs.mkdirs("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/raw")
dbutils.fs.mkdirs("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/bronze")
dbutils.fs.mkdirs("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/silver")
dbutils.fs.mkdirs("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/gold")

# %% [markdown]
# ## load orders

# %% [markdown]
# ### load orders

# %%
orders_df = spark.read.option("header","true").option("inferSchema","true") \
.csv("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/raw/orders.csv")

orders_df.write.format("delta").mode("overwrite") \
.save("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/bronze/orders")

# %% [markdown]
# ### load customers

# %%
customers_df = spark.read \
.option("header","true") \
.option("inferSchema","true") \
.csv("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/raw/customers.csv")

customers_df.write \
.format("delta") \
.mode("overwrite") \
.save("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/bronze/customers")

# %% [markdown]
# ### load products

# %%
products_df = spark.read \
.option("header","true") \
.option("inferSchema","true") \
.csv("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/raw/products.csv")

products_df.write \
.format("delta") \
.mode("overwrite") \
.save("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/bronze/products")

# %% [markdown]
# ### load payments

# %%
payments_df = spark.read \
.option("header","true") \
.option("inferSchema","true") \
.csv("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/raw/payments.csv")

payments_df.write \
.format("delta") \
.mode("overwrite") \
.save("/Volumes/ecommerce_catalog/ecommerce_schema/ecommerce_volume/bronze/payments")
